# %%
import pandas as pd

# %%
matches = pd.read_csv("../data/matches.csv", index_col=0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result  gf  ga  \
# 1  2022-08-07  16:30  Premier League  Matchweek 1  Sun  Away      W   2   0
# 2  2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W   4   0
# 3  2022-08-21  16:30  Premier League  Matchweek 3  Sun  Away      D   3   3
# 4  2022-08-27  15:00  Premier League  Matchweek 4  Sat  Home      W   4   2
# 5  2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W   6   0
#
#           opponent  ...  match report  notes    sh   sot  dist   fk pk pkatt  \
# 1         West Ham  ...  Match Report    NaN  13.0   1.0  18.7  1.0  1     1
# 2      Bournemouth  ...  Match Report    NaN  19.0   7.0  17.5  0.0  0     0
# 3    Newcastle Utd  ...  Match Report    NaN  21.0  10.0  16.2  1.0  0     0
# 4   Crystal Palace  ...  Match Report    NaN  18.0   5.0  14.1  0.0  0     0
# 5  Nott'ham Forest  ...  Match Report    NaN  17.0   9.0  14.8  0.0  0     0
#
#    season            team
# 1    2024  ManchesterCity
# 2    2024  ManchesterCity
# 3    2024  ManchesterCity
# 4    2024  ManchesterCity
# 5    2024  ManchesterCity
#
# [5 rows x 27 columns]

# %%
matches.shape
# Out:
# (3040, 27)

# %%
38 * 20 * 4
# Out:
# 3040

# %%
matches["team"].value_counts()
# Out:
# ManchesterCity            152
# CrystalPalace             152
# Southampton               152
# LeicesterCity             152
# Everton                   152
# WestHamUnited             152
# Arsenal                   152
# Chelsea                   152
# WolverhamptonWanderers    152
# TottenhamHotspur          152
# AstonVilla                152
# BrightonandHoveAlbion     152
# Liverpool                 152
# NewcastleUnited           152
# ManchesterUnited          152
# LeedsUnited               114
# Burnley                   114
# Fulham                     76
# Brentford                  76
# Bournemouth                76
# Watford                    76
# NorwichCity                76
# SheffieldUnited            76
# NottinghamForest           38
# WestBromwichAlbion         38
# Name: team, dtype: int64

# %%
matches["round"].value_counts()
# Out:
# Matchweek 1     80
# Matchweek 30    80
# Matchweek 23    80
# Matchweek 12    80
# Matchweek 24    80
# Matchweek 25    80
# Matchweek 26    80
# Matchweek 27    80
# Matchweek 29    80
# Matchweek 31    80
# Matchweek 2     80
# Matchweek 33    80
# Matchweek 34    80
# Matchweek 28    80
# Matchweek 35    80
# Matchweek 36    80
# Matchweek 37    80
# Matchweek 32    80
# Matchweek 22    80
# Matchweek 21    80
# Matchweek 7     80
# Matchweek 20    80
# Matchweek 3     80
# Matchweek 4     80
# Matchweek 5     80
# Matchweek 6     80
# Matchweek 8     80
# Matchweek 9     80
# Matchweek 10    80
# Matchweek 11    80
# Matchweek 13    80
# Matchweek 14    80
# Matchweek 15    80
# Matchweek 16    80
# Matchweek 17    80
# Matchweek 18    80
# Matchweek 19    80
# Matchweek 38    80
# Name: round, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf                int64
# ga                int64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk                int64
# pkatt             int64
# season            int64
# team             object
# dtype: object

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                       int64
# ga                       int64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                  float64
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                       int64
# pkatt                    int64
# season                   int64
# team                    object
# dtype: object

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.day_of_week

# %%
matches["target"] = (matches["result"] == "W").astype("int")

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2022-12-01']

# %%
test = matches[matches["date"] > '2022-12-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.5982905982905983

# %%
combined = pd.DataFrame(dict(actual=test['target'], prediction=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# prediction    0   1
# actual
# 0           224  63
# 1           125  56

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds)
# Out:
# 0.47058823529411764

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("ManchesterCity")

# %%
def rolling_average(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed="left").mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
rolling_average(group, cols, new_cols)
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 4  2019-08-31  15:00  Premier League   Matchweek 4  Sat  Home      W   4   0
# 5  2019-09-14  17:30  Premier League   Matchweek 5  Sat  Away      L   2   3
# 7  2019-09-21  15:00  Premier League   Matchweek 6  Sat  Home      W   8   0
# 9  2019-09-28  17:30  Premier League   Matchweek 7  Sat  Away      W   3   1
# 11 2019-10-06  14:00  Premier League   Matchweek 8  Sun  Home      L   0   2
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 52 2023-05-06  15:00  Premier League  Matchweek 35  Sat  Home      W   2   1
# 54 2023-05-14  14:00  Premier League  Matchweek 36  Sun  Away      W   3   0
# 56 2023-05-21  16:00  Premier League  Matchweek 37  Sun  Home      W   1   0
# 57 2023-05-24  20:00  Premier League  Matchweek 32  Wed  Away      D   1   1
# 58 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      L   0   1
#
#         opponent  ...  day_code  target  gf_rolling  ga_rolling sh_rolling  \
# 4       Brighton  ...         5       1    3.333333    1.000000  20.333333
# 5   Norwich City  ...         5       0    3.000000    1.000000  21.000000
# 7        Watford  ...         5       1    3.000000    1.333333  19.333333
# 9        Everton  ...         5       1    4.666667    1.000000  22.333333
# 11        Wolves  ...         6       0    4.333333    1.333333  23.666667
# ..           ...  ...       ...     ...         ...         ...        ...
# 52  Leeds United  ...         5       1    3.000000    0.666667  13.666667
# 54       Everton  ...         6       1    2.333333    0.666667  14.666667
# 56       Chelsea  ...         6       1    2.666667    0.333333  14.000000
# 57      Brighton  ...         2       0    2.000000    0.333333  13.666667
# 58     Brentford  ...         6       0    1.666667    0.333333  12.333333
#
#    sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 4     7.666667    15.633333   0.000000    0.333333       0.333333
# 5     7.000000    15.200000   0.333333    0.000000       0.000000
# 7     6.333333    15.100000   0.333333    0.000000       0.000000
# 9     8.000000    15.133333   1.000000    0.333333       0.333333
# 11    8.666667    14.900000   1.000000    0.333333       0.333333
# ..         ...          ...        ...         ...            ...
# 52    8.000000    15.433333   0.000000    0.333333       0.333333
# 54    7.000000    16.366667   0.666667    0.333333       0.666667
# 56    5.666667    18.100000   1.333333    0.000000       0.333333
# 57    4.000000    18.933333   1.333333    0.000000       0.333333
# 58    3.333333    17.333333   0.666667    0.000000       0.000000
#
# [149 rows x 40 columns]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_average(x, cols,new_cols))

# %%
matches_rolling = matches_rolling.droplevel("team")

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < "2022-12-01"]
    test = data[data["date"] > "2022-12-01"]
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test['target'], prediction=preds), index=test.index)
    precision = precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.6105263157894737

# %%
combined
# Out:
#       actual  prediction
# 125        1           1
# 126        1           1
# 127        0           1
# 128        1           1
# 129        1           0
# ...      ...         ...
# 2957       0           0
# 2958       1           0
# 2959       0           0
# 2960       0           0
# 2961       0           0
#
# [468 rows x 2 columns]

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined
# Out:
#       actual  prediction       date                    team        opponent  \
# 125        1           1 2022-12-26                 Arsenal        West Ham
# 126        1           1 2022-12-31                 Arsenal        Brighton
# 127        0           1 2023-01-03                 Arsenal   Newcastle Utd
# 128        1           1 2023-01-15                 Arsenal       Tottenham
# 129        1           0 2023-01-22                 Arsenal  Manchester Utd
# ...      ...         ...        ...                     ...             ...
# 2957       0           0 2023-04-29  WolverhamptonWanderers        Brighton
# 2958       1           0 2023-05-06  WolverhamptonWanderers     Aston Villa
# 2959       0           0 2023-05-13  WolverhamptonWanderers  Manchester Utd
# 2960       0           0 2023-05-20  WolverhamptonWanderers         Everton
# 2961       0           0 2023-05-28  WolverhamptonWanderers         Arsenal
#
#      result
# 125       W
# 126       W
# 127       D
# 128       W
# 129       W
# ...     ...
# 2957      L
# 2958      W
# 2959      L
# 2960      D
# 2961      L
#
# [468 rows x 6 columns]

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {
    "Brighton and Hove Albion": "Brighton",
    "WolverhamptonWanderers": "Wolves",
    "Manchester United": "Manchester Utd",
    "Tottenham Hotspur": "Tottenham",
    "Newcastle United": "Newcastle Utd",
    "West Ham United": "West Ham Utd"
}

mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged
# Out:
#      actual_x  prediction_x       date                  team_x  \
# 0           1             1 2022-12-26                 Arsenal
# 1           1             1 2022-12-31                 Arsenal
# 2           0             1 2023-01-03                 Arsenal
# 3           1             1 2023-01-15                 Arsenal
# 4           1             0 2023-01-22                 Arsenal
# ..        ...           ...        ...                     ...
# 205         0             0 2023-04-29  WolverhamptonWanderers
# 206         1             0 2023-05-06  WolverhamptonWanderers
# 207         0             0 2023-05-13  WolverhamptonWanderers
# 208         0             0 2023-05-20  WolverhamptonWanderers
# 209         0             0 2023-05-28  WolverhamptonWanderers
#
#          opponent_x result_x new_team_x  actual_y  prediction_y  \
# 0          West Ham        W    Arsenal         0             0
# 1          Brighton        W    Arsenal         0             0
# 2     Newcastle Utd        D    Arsenal         0             0
# 3         Tottenham        W    Arsenal         0             0
# 4    Manchester Utd        W    Arsenal         0             1
# ..              ...      ...        ...       ...           ...
# 205        Brighton        L     Wolves         1             0
# 206     Aston Villa        W     Wolves         0             0
# 207  Manchester Utd        L     Wolves         1             1
# 208         Everton        D     Wolves         0             0
# 209         Arsenal        L     Wolves         1             0
#
#                     team_y opponent_y result_y             new_team_y
# 0            WestHamUnited    Arsenal        L          WestHamUnited
# 1    BrightonandHoveAlbion    Arsenal        L  BrightonandHoveAlbion
# 2          NewcastleUnited    Arsenal        D        NewcastleUnited
# 3         TottenhamHotspur    Arsenal        L       TottenhamHotspur
# 4         ManchesterUnited    Arsenal        L       ManchesterUnited
# ..                     ...        ...      ...                    ...
# 205  BrightonandHoveAlbion     Wolves        W  BrightonandHoveAlbion
# 206             AstonVilla     Wolves        L             AstonVilla
# 207       ManchesterUnited     Wolves        W       ManchesterUnited
# 208                Everton     Wolves        D                Everton
# 209                Arsenal     Wolves        W                Arsenal
#
# [210 rows x 13 columns]

# %%
merged[(merged["prediction_x"] == 1) & (merged["prediction_y"] ==0)]["actual_x"].value_counts()
# Out:
# 1    21
# 0    14
# Name: actual_x, dtype: int64
